# %%
import matplotlib.pyplot as plt

# %%
x_axis = []
for i in range(1,1001):
    x_axis.append(i)

# %%
lines = []
cora_r11_acc = []
with open('oriadj_ptb15_cora_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r11_acc.append(round(float(parser[7])*100,2)) 
    
lines = []
cora_r21_acc = []
with open('oriadj_ptb15_cora_r21.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r21_acc.append(round(float(parser[7])*100,2)) 

lines = []
cora_r51_acc = []
with open('oriadj_ptb15_cora_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r51_acc.append(round(float(parser[7])*100,2)) 

lines = []
cora_r101_acc = []
with open('oriadj_ptb15_cora_r101.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r101_acc.append(round(float(parser[7])*100,2)) 
    
lines = []
cora_r12_acc = []
with open('oriadj_ptb15_cora_r12.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r12_acc.append(round(float(parser[7])*100,2)) 
    
lines = []
cora_r11_acc_ptb25 = []
with open('oriadj_ptb25_cora_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r11_acc_ptb25.append(round(float(parser[7])*100,2)) 
    
lines = []
cora_r11_acc_ptb5 = []
with open('oriadj_ptb5_cora_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r11_acc_ptb5.append(round(float(parser[7])*100,2)) 
    
lines = []
cora_r51_acc_ptb25 = []
with open('oriadj_ptb25_cora_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r51_acc_ptb25.append(round(float(parser[7])*100,2)) 
    
lines = []
cora_r11_acc_ptb25 = []
with open('oriadj_ptb25_cora_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    cora_r11_acc_ptb25.append(round(float(parser[7])*100,2))

# %%
lines = []
citeseer_r11_acc_ptb15 = []
with open('oriadj_ptb15_citeseer_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r11_acc_ptb15.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r21_acc_ptb15 = []
with open('oriadj_ptb15_citeseer_r21.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r21_acc_ptb15.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r51_acc_ptb15 = []
with open('oriadj_ptb15_citeseer_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r51_acc_ptb15.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r101_acc_ptb15 = []
with open('oriadj_ptb15_citeseer_r101.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r101_acc_ptb15.append(round(float(parser[7])*100,2)) 

lines = []
citeseer_r12_acc_ptb15 = []
with open('oriadj_ptb15_citeseer_r12.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r12_acc_ptb15.append(round(float(parser[7])*100,2))

# %%
lines = []
citeseer_r51_acc_ptb5 = []
with open('oriadj_ptb5_citeseer_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r51_acc_ptb5.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r11_acc_ptb5 = []
with open('oriadj_ptb5_citeseer_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r11_acc_ptb5.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r51_acc_ptb25 = []
with open('oriadj_ptb25_citeseer_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r51_acc_ptb25.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r11_acc_ptb25 = []
with open('oriadj_ptb25_citeseer_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r11_acc_ptb25.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r11_acc_ptb35 = []
with open('oriadj_ptb35_citeseer_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r11_acc_ptb35.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r11_acc_ptb0 = []
with open('oriadj_ptb0_citeseer_r11.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r11_acc_ptb0.append(round(float(parser[7])*100,2)) 

lines = []
citeseer_r51_acc_ptb35 = []
with open('oriadj_ptb35_citeseer_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r51_acc_ptb35.append(round(float(parser[7])*100,2)) 
    
lines = []
citeseer_r51_acc_ptb0 = []
with open('oriadj_ptb0_citeseer_r51.txt') as f:
    lines = f.readlines()
for line in lines:
    parser = line.split(' ')
    citeseer_r51_acc_ptb0.append(round(float(parser[7])*100,2))

# %%
print('cora r11 ptb15 epoch : ',len(cora_r11_acc), '/ max : ',max(cora_r11_acc))
print('cora r21 ptb15 epoch : ',len(cora_r21_acc), '/ max : ',max(cora_r21_acc))
print('cora r51 ptb15 epoch : ',len(cora_r51_acc), '/ max : ',max(cora_r51_acc))
print('cora r101 ptb15 epoch : ',len(cora_r101_acc), '/ max : ',max(cora_r101_acc))
print('cora r12 ptb15 epoch : ',len(cora_r12_acc), '/ max : ',max(cora_r12_acc))
print('----------------------------------------------')
print('cora r11 ptb5 epoch : ',len(cora_r11_acc_ptb5), '/ max : ',max(cora_r11_acc_ptb5))
print('cora r51 ptb5 epoch : ',len(cora_r51_acc_ptb5), '/ max : ',max(cora_r51_acc_ptb5))
print('cora r11 ptb25 epoch : ',len(cora_r11_acc_ptb25), '/ max : ',max(cora_r11_acc_ptb25))
print('cora r51 ptb25 epoch : ',len(cora_r51_acc_ptb25), '/ max : ',max(cora_r51_acc_ptb25))
print('----------------------------------------------')
print('citeseer r11 ptb15 epoch : ',len(citeseer_r11_acc_ptb15), '/ max : ',max(citeseer_r11_acc_ptb15))
print('citeseer r21 ptb15 epoch : ',len(citeseer_r21_acc_ptb15), '/ max : ',max(citeseer_r21_acc_ptb15))
print('citeseer r51 ptb15 epoch : ',len(citeseer_r51_acc_ptb15), '/ max : ',max(citeseer_r51_acc_ptb15))
print('citeseer r101 ptb15 epoch : ',len(citeseer_r101_acc_ptb15), '/ max : ',max(citeseer_r101_acc_ptb15))
print('citeseer r12 ptb15 epoch : ',len(citeseer_r12_acc_ptb15), '/ max : ',max(citeseer_r12_acc_ptb15))
print('----------------------------------------------')
print('citeseer r11 ptb0 epoch : ',len(citeseer_r11_acc_ptb0), '/ max : ',max(citeseer_r11_acc_ptb0))
print('citeseer r51 ptb0 epoch : ',len(citeseer_r51_acc_ptb0), '/ max : ',max(citeseer_r51_acc_ptb0))
print('citeseer r11 ptb5 epoch : ',len(citeseer_r11_acc_ptb5), '/ max : ',max(citeseer_r11_acc_ptb5))
print('citeseer r51 ptb5 epoch : ',len(citeseer_r51_acc_ptb5), '/ max : ',max(citeseer_r51_acc_ptb5))
print('citeseer r11 ptb25 epoch : ',len(citeseer_r11_acc_ptb25), '/ max : ',max(citeseer_r11_acc_ptb25))
print('citeseer r51 ptb25 epoch : ',len(citeseer_r51_acc_ptb25), '/ max : ',max(citeseer_r51_acc_ptb25))
print('citeseer r11 ptb35 epoch : ',len(citeseer_r11_acc_ptb35), '/ max : ',max(citeseer_r11_acc_ptb35))
print('citeseer r51 ptb35 epoch : ',len(citeseer_r51_acc_ptb35), '/ max : ',max(citeseer_r51_acc_ptb35))
# Out:
# cora r11 ptb15 epoch :  1000 / max :  80.32
# cora r21 ptb15 epoch :  1000 / max :  79.12
# cora r51 ptb15 epoch :  739 / max :  77.11
# cora r101 ptb15 epoch :  1000 / max :  75.9
# cora r12 ptb15 epoch :  714 / max :  78.71
# ----------------------------------------------
# cora r11 ptb5 epoch :  1000 / max :  84.74
# cora r51 ptb5 epoch :  1000 / max :  84.74
# cora r11 ptb25 epoch :  1000 / max :  77.11
# cora r51 ptb25 epoch :  1000 / max :  73.9
# ----------------------------------------------
# citeseer r11 ptb15 epoch :  1000 / max :  77.73
# citeseer r21 ptb15 epoch :  1000 / max :  75.83
# citeseer r51 ptb15 epoch :  1000 / max :  77.25
# citeseer r101 ptb15 epoch :  1000 / max :  77.25
# citeseer r12 ptb15 epoch :  2000 / max :  75.83
# ----------------------------------------------
# citeseer r11 ptb0 epoch :  1000 / max :  74.41
# citeseer r51 ptb0 epoch :  1000 / max :  76.3
# citeseer r11 ptb5 epoch :  1000 / max :  76.3
# ...

# %%
n = 700
plt.plot(x_axis[:n], cora_r11_acc[:n], color='red', label='ptb15 1:1')
plt.plot(x_axis[:n], cora_r21_acc[:n], color='blue', label='ptb15 2:1')
plt.plot(x_axis[:n], cora_r51_acc[:n], color='black', label='ptb15 5:1')
plt.plot(x_axis[:n], cora_r101_acc[:n], color='green', label='ptb15 10:1')
plt.plot(x_axis[:n], cora_r12_acc[:n], color='orange', label='ptb15 1:2')

plt.title("Cora inner/outer step Experiment") # title
plt.ylabel("acc_val") # y label
plt.xlabel("epochs") # x label
plt.legend()
plt.show()

# %%
n = 720
plt.plot(x_axis[:n], cora_r51_acc_ptb5[:n], color='red', label='ptb5 5:1')
plt.plot(x_axis[:n], cora_r11_acc_ptb5[:n], color='blue', label='ptb5 1:1')
plt.plot(x_axis[:n], cora_r11_acc[:n], color='purple', label='ptb15 1:1')
plt.plot(x_axis[:n], cora_r51_acc[:n], color='brown', label='ptb15 5:1')
plt.plot(x_axis[:n], cora_r51_acc_ptb25[:n], color='green', label='ptb25 5:1')
plt.plot(x_axis[:n], cora_r11_acc_ptb25[:n], color='orange', label='ptb25 1:1')

plt.title("Cora ptb rate Experiment") # title
plt.ylabel("acc_val") # y label
plt.xlabel("epochs") # x label
plt.legend()
plt.show()

# %%
n = 700
plt.plot(x_axis[:n], citeseer_r11_acc_ptb15[:n], color='red', label='ptb15 1:1')
plt.plot(x_axis[:n], citeseer_r21_acc_ptb15[:n], color='blue', label='ptb15 2:1')
plt.plot(x_axis[:n], citeseer_r51_acc_ptb15[:n], color='black', label='ptb15 5:1')
plt.plot(x_axis[:n], citeseer_r101_acc_ptb15[:n], color='green', label='ptb15 10:1')
plt.plot(x_axis[:n], citeseer_r12_acc_ptb15[:n], color='orange', label='ptb15 1:2')

plt.title("Citeseer inner/outer step Experiment") # title
plt.ylabel("acc_val") # y label
plt.xlabel("epochs") # x label
plt.legend()
plt.show()

# %%
n = 700
plt.plot(x_axis[:n], citeseer_r51_acc_ptb0[:n], color='red', label='ptb0 5:1')
plt.plot(x_axis[:n], citeseer_r11_acc_ptb0[:n], color='blue', label='ptb0 1:1')
plt.plot(x_axis[:n], citeseer_r51_acc_ptb25[:n], color='brown', label='ptb25 5:1')
plt.plot(x_axis[:n], citeseer_r11_acc_ptb25[:n], color='purple', label='ptb25 1:1')
plt.plot(x_axis[:n], citeseer_r51_acc_ptb35[:n], color='green', label='ptb35 5:1')
plt.plot(x_axis[:n], citeseer_r11_acc_ptb35[:n], color='orange', label='ptb35 1:1')

plt.title("Citeseer ptb rate Experiment") # title
plt.ylabel("acc_val") # y label
plt.xlabel("epochs") # x label
plt.legend()
plt.show()

# %%
n = 700
plt.plot(x_axis[:n], citeseer_r51_acc_ptb0[:n], color='red', label='ptb0 5:1')
plt.plot(x_axis[:n], citeseer_r11_acc_ptb0[:n], color='blue', label='ptb0 1:1')
plt.plot(x_axis[:n], citeseer_r51_acc_ptb35[:n], color='green', label='ptb35 5:1')
plt.plot(x_axis[:n], citeseer_r11_acc_ptb35[:n], color='orange', label='ptb35 1:1')

plt.title("Cora ptb rate Experiment") # title
plt.ylabel("acc_val") # y label
plt.xlabel("epochs") # x label
plt.legend()
plt.show()
